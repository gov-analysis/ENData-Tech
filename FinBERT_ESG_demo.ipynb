# %% [markdown]
# ## This code demonstrates how to apply FinBERT fine-tuned for ESG classification
#
# > *Created by Allen Huang (HKUST) and Xiangyu Li (USC)*
#
#
# ## 1. Set up Fine-Tuned FinBERT Model
# First check GPU selection: Select Menu "Runtime" -> Change runtime type -> select "GPU"

# %%
# !pip install transformers
from transformers import BertTokenizer, BertForSequenceClassification, pipeline

# load the FinBERT fine-tuned ESG 9-category model and the corresponding tokernizer (used for preprocessing input sentences)
finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-esg-9-categories', num_labels = 9)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-esg-9-categories')

# load model on GPU/CPU
import torch
# load model on GPU if available
if torch.cuda.is_available():
    device = torch.device("cuda")
    # put the model on GPU
    finbert.to(device)
    print(f'There are {torch.cuda.device_count()} GPU(s) available.')
    print('Model loaded on:', torch.cuda.get_device_name(0))

# load model on CPU if GPU is not available
else:
    device = torch.device("cpu")
    # put the model on CPU
    finbert.to(device)
    print('No GPU available, model loaded on CPU.')
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]
# There are 1 GPU(s) available.
# Model loaded on: Tesla T4

# %% [markdown]
# ## 2. Load sample data set (225 sentences = 25 x 9 categories)

# %%
import pandas as pd

# import sample data
data = pd.read_csv('https://github.com/allenhhuang/FinBERT/raw/main/FinBERT%20test%20sample.csv').dropna(subset = ['Sentence', 'Label']).reset_index(drop = True)

# 9 categories and labels
label_map = {'Climate Change': 'CC',
             'Natural Capital': 'NC',
             'Pollution & Waste': 'PW',
             'Human Capital': 'HC',
             'Product Liability': 'PL',
             'Community Relations': 'CR',
             'Corporate Governance': 'CG',
             'Business Ethics & Values': 'BE',
             'Non-ESG': 'N'}

label_map_reverse = {'CC': 'Climate Change',
             'NC': 'Natural Capital',
             'PW': 'Pollution & Waste',
             'HC': 'Human Capital',
             'PL': 'Product Liability',
             'CR': 'Community Relations',
             'CG': 'Corporate Governance',
             'BE': 'Business Ethics & Values',
             'N': 'Non-ESG'}

# print the distribution of categories in sample data and first 5 observations
print(data['Label'].value_counts())
print('First 5 observations in sample data:')
data.head(5)
# Out:
# Label
# PL    25
# CG    25
# HC    25
# CC    25
# BE    25
# CR    25
# PW    25
# N     25
# NC    25
# Name: count, dtype: int64
# First 5 observations in sample data:
#                                             Sentence Label
# 0  Importantly, our measure of MRSL compliance is...    PL
# 1  It assists NIKE, Inc. in accomplishing its obj...    CG
# 2  Internally, our Women of Nike & Friends Networ...    HC
# 3  In Belgium, at our Converse European Logistics...    CC
# 4  The Company will not make political contributi...    BE

# %% [markdown]
# ### 2.1. OPTION 1: Output each category's probability

# %%
# define a function to output the probability of each category
from scipy.special import softmax
import numpy as np

def augmented_nlp(sentence):
  '''input any sentence, output FinBERT label, Predicted Label score/probability,
     and the probabilities that the sentence belongs to each category'''
  # preprocess the sentence
  input = tokenizer(sentence, return_tensors = 'pt', padding = True).to(device)
  # finbert raw output
  output = finbert(**input)[0]
  # convert the output to probabilities corresponding to each category
  probs = softmax(output.cpu().detach().numpy(), axis = 1)
  # get the numeric label with the highest probability
  value = np.argmax(probs, axis = -1)
  # get the textual label
  label = finbert.config.id2label[value[0]]
  # get the highest probability
  score = np.max(probs, axis = -1)

  return {'label': label,
          'score': score[0],
          'probabilities': probs[0].tolist()}

# demonstrate the output
print('augmented nlp output: ', augmented_nlp('For 2002, our total net emissions were approximately 60 million metric tons of CO2 equivalents for all businesses and operations we have ﬁnancial interests in, based on its equity share in those businesses and operations.'))
# Out:
# augmented nlp output:  {'label': 'Climate Change', 'score': 0.9955656, 'probabilities': [0.9955655932426453, 0.0006281687528826296, 0.0010522982338443398, 0.00031542990473099053, 0.00038357896846719086, 0.0002711373381316662, 0.0009126343647949398, 0.00028890068642795086, 0.000582217937335372]}

# %%
# Process sample data and download full output in a CSV file

# define the output structure
header = ['No.', 'Sentence', 'Label', 'FinBERT label', 'FinBERT score', 'Correct label'] + list(finbert.config.id2label.values())
result = []

# loop through the sentences
for i, row in data.iterrows():
  # sentence number
  id = str(i+1)
  print('Sentence number: ' + id)

  # sentence
  sentence = row['Sentence']
  print('Sentence: ' + sentence)

  # use the augmented_nlp function to process the sentence, get finbert label, score, and probabilities
  finbert_output = augmented_nlp(sentence)

  # label and score
  manual_label = row['Label']
  finbert_label = label_map[finbert_output['label']]
  finbert_score = finbert_output['score']
  print('Manual label: ' + label_map_reverse[manual_label])
  print('FinBERT label: ' + finbert_output['label'])
  print('FinBERT score: ', finbert_score)

  # probabilities
  finbert_probs = finbert_output['probabilities']

  print('-'*50)
  print()

  # combine all the output above into one row of observation
  row = [id, sentence, manual_label, finbert_label, finbert_score, 1*(manual_label==finbert_label)] + finbert_probs
  result.append(row)

# consolidate the output into a dataframe
result_df_full = pd.DataFrame(result, columns = header)

# save the output in the csv format
result_df_full.to_csv('FinBERT ESG9Class output full.csv', index = False)
# download the output to the local computer
from google.colab import files
files.download('FinBERT ESG9Class output full.csv')
# display the output
result_df_full
# Out:
# Sentence number: 1
# Sentence: Importantly, our measure of MRSL compliance is based at the facility level and not solely on NIKE production.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.7817407
# --------------------------------------------------
#
# Sentence number: 2
# Sentence: It assists NIKE, Inc. in accomplishing its objectives by partnering with management to build and maintain effective risk management, control and governance processes.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9760307
# --------------------------------------------------
#
# Sentence number: 3
# Sentence: Internally, our Women of Nike & Friends Network – through NikeUNITED – continues to play a significant role in retention and promotion of women through its robust, interactive programming.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.81121886
# --------------------------------------------------
#
# Sentence number: 4
# Sentence: In Belgium, at our Converse European Logistics Campus, a rooftop solar array also went live and is estimated to produce 3,000 MWh annually, covering a significant portion of the facility’s electricity needs.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9954951
# --------------------------------------------------
#
# Sentence number: 5
# Sentence: The Company will not make political contributions related to a U.S. federal election, including candidates, political parties or political action committees.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9686669
# --------------------------------------------------
#
# Sentence number: 6
# Sentence: For Compensation Committee members, the Board must consider all factors specifically relevant to determining whether a director has a relationship to the Company that is material to the ability to be independent from management in connection with the duties of a Compensation Committee member, including the source of compensation of the director, any consulting, advisory or other compensatory fee paid by the Company to the director; and whether the director is affiliated with the Company or any subsidiary.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9957355
# --------------------------------------------------
#
# Sentence number: 7
# Sentence: This includes a $40 million commitment over the next four years to invest in and support organizations focused on economic empowerment to address racial inequality for the Black community
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9808414
# --------------------------------------------------
#
# Sentence number: 8
# Sentence: As gender inequality in the workplace remains a pervasive global issue, we strive to enable women to reach their full career potential while staying committed to fostering an environment that supports them in the workplace.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9943297
# --------------------------------------------------
#
# Sentence number: 9
# Sentence: We do not offer, promise, give or accept money or anything of value to or from third parties to get an improper business advantage.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.96235436
# --------------------------------------------------
#
# Sentence number: 10
# Sentence: The Board will meet at least four times per year.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9942483
# --------------------------------------------------
#
# Sentence number: 11
# Sentence: Through FY21, our creation-led waste target was behind plan
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.986245
# --------------------------------------------------
#
# Sentence number: 12
# Sentence: Nike takes all allegations of misconduct or other wrongdoing seriously and will investigate them thoroughly
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.97067934
# --------------------------------------------------
#
# Sentence number: 13
# Sentence: Effective corporate management and oversight of Occupational Safety & Health (OS&H) implementation at the highest level of an organization enables more effective and sustained health and safety programs and performance.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9930922
# --------------------------------------------------
#
# Sentence number: 14
# Sentence: For employees who continued to work from home due to COVID-19 health and safety measures, we provided them with select technology and ergonomic products through a partnership with Staples
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9939319
# --------------------------------------------------
#
# Sentence number: 15
# Sentence: When we prioritize the well-being of our employees – inspiring and enabling everyone to deliver their best work – we bring our best as a team.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.99424416
# --------------------------------------------------
#
# Sentence number: 16
# Sentence: We continue to evolve and expand our standards and programs to drive improved outcomes for workers in our supply chain and communities where suppliers operate and enhanced value for NIKE and suppliers.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.99298406
# --------------------------------------------------
#
# Sentence number: 17
# Sentence: Reported EBIT increased 76% driven by higher revenues, lower selling and administrative expense as a percent of revenues and gross margin expansion.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.99355537
# --------------------------------------------------
#
# Sentence number: 18
# Sentence: In addition to this Policy, any and all political contributions must also comply with Company’s code of ethics, the Foreign Corrupt Practices Act and all other applicable laws and regulations in the jurisdictions in which the contributions will be made.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.98674715
# --------------------------------------------------
#
# Sentence number: 19
# Sentence: Hundreds of thousands of raw materials tests have been achieved since the program’s launch, generating millions of chemical data points that allow us to proactively control the chemical compliance of our products.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.8281807
# --------------------------------------------------
#
# Sentence number: 20
# Sentence: Due to the substantial positive impact on our inbound carbon emissions (air freight is on average 42 times more carbon intensive than ocean freight), NIKE is working to not return to pre-pandemic air freight usage, through our Move to Zero air freight program.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9935777
# --------------------------------------------------
#
# Sentence number: 21
# Sentence: Even with the spread of COVID-19 in the second half of FY20, our materials suppliers were able to maintain their water-efficiency gains, demonstrating that our efficiency initiatives have been operationalized and the water savings are real.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.98468995
# --------------------------------------------------
#
# Sentence number: 22
# Sentence: We know that some kids and communities face more barriers than others – whether that be accessing education, sport, or mentorship – so we invest in community organizations and programs that aim to remove barriers for all kids and communities.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9887636
# --------------------------------------------------
#
# Sentence number: 23
# Sentence: We are obligated to report requests to comply with certain boycotts to the U.S. government
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.8991196
# --------------------------------------------------
#
# Sentence number: 24
# Sentence: In FY21, we completed the LeBron James and Serena Williams buildings, both of which achieved LEED Platinum certification.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9792783
# --------------------------------------------------
#
# Sentence number: 25
# Sentence: NIKE Global Risk Management (GRM) is an independent and objective audit and risk organization that is guided by a philosophy of enhancing and protecting NIKE, Inc.’s value and brand through world-class risk management capabilities.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9808169
# --------------------------------------------------
#
# Sentence number: 26
# Sentence: We’re putting innovation resources toward the exploration of other leather alternatives from non-animal sources.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.93880033
# --------------------------------------------------
#
# Sentence number: 27
# Sentence: Considering all freshwater use (rather than just for dyeing and finishing), its FY16 baseline was 205 liters of freshwater per kilogram of dyed and finished fabric, making it one of the least efficient water users in the scope of this target
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9796571
# --------------------------------------------------
#
# Sentence number: 28
# Sentence: We aim to move to high-recycled percentage formulations that maintain material benefits while lowering environmental impact.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9794012
# --------------------------------------------------
#
# Sentence number: 29
# Sentence: At each Board meeting, the CRS&G Committee reports to the Board on purpose highlights and key developments.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.99469614
# --------------------------------------------------
#
# Sentence number: 30
# Sentence: NIKE is well ahead of our recycled polyester plan in both footwear and apparel.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.96165556
# --------------------------------------------------
#
# Sentence number: 31
# Sentence: NIKE Apparel’s goal is to increase efficiency in our product designs earlier in our creation and development process, which will reduce waste when those products are manufactured.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.98967135
# --------------------------------------------------
#
# Sentence number: 32
# Sentence: In Greater China, alternative transportation methods for outbound shipping have helped reduce carbon emissions.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9943967
# --------------------------------------------------
#
# Sentence number: 33
# Sentence: Revenues for Converse increased 19% and 16%, on a reported and currencyneutral basis, respectively, led by strong double-digit growth in digital.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9938869
# --------------------------------------------------
#
# Sentence number: 34
# Sentence: Investing in more equal, inclusive, and active communities isn’t just the right thing to do as a business, it’s also critical for helping to realize a thriving future for our kids, communities, and the planet.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9869452
# --------------------------------------------------
#
# Sentence number: 35
# Sentence: During FY21, these suppliers completed all of the foundational requirements of the program, which includes having their science-based Scope 1 and 2 emission targets validated by the World Resources Institute (WRI).
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.99148726
# --------------------------------------------------
#
# Sentence number: 36
# Sentence: To help us achieve full RSL compliance, we aligned our RSL with guidelines established by the Apparel and Footwear International RSL Management (AFIRM) Group.
# Manual label: Product Liability
# FinBERT label: Corporate Governance
# FinBERT score:  0.924565
# --------------------------------------------------
#
# Sentence number: 37
# Sentence: It is expected that a director who is unable to attend a Board meeting, committee meeting or annual shareholder meeting (which, it is understood, will occur on occasion) will notify the Chair of the Board or the chair of the relevant committee.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9953231
# --------------------------------------------------
#
# Sentence number: 38
# Sentence: In addition to following local government restrictions, the World Health Organization (WHO), and Centers for Disease Control and Prevention (CDC) requirements for protecting workers and preventing community spread, we are continually expanding fundamental capabilities on how to anticipate, recognize, evaluate, and control occupational health issues in the workplace.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9928919
# --------------------------------------------------
#
# Sentence number: 39
# Sentence: For example, in India, we offered early payout of our Performance Share Plan to support immediate liquidity needs, we enhanced telemedicine and EAP access, and expanded EAP and telemedicine support for family members of our employees who reside in India.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9743773
# --------------------------------------------------
#
# Sentence number: 40
# Sentence: NIKE, Inc. gross margin increased 140 basis points primarily due to annualizing the impacts of COVID-19 including lower factory cancellation charges, lower inventoryobsolescence reserves as well as the favorable rate impact of fixed supply chain costs on a higher volume of wholesale shipments.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.99381024
# --------------------------------------------------
#
# Sentence number: 41
# Sentence: To that end, it is the role of all managers who receive concerns of misconduct or violations of the Code from employees to report those allegations using an appropriate reporting channel, including the Speak Up Portal, Human Resources and the Ethics & Compliance Office.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.97191477
# --------------------------------------------------
#
# Sentence number: 42
# Sentence: At the same time, it is the policy of the Board that directors will not stand for re-election after reaching age 72.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.99486476
# --------------------------------------------------
#
# Sentence number: 43
# Sentence: While foreign currency markets remain volatile, in part due to geopolitical dynamics which may lead to a stronger U.S. Dollar, we continue to see opportunities to drive futuregrowth and profitability.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.99062496
# --------------------------------------------------
#
# Sentence number: 44
# Sentence: The Company may from time to time directly engage external registered lobbyists to assist the Company in monitoring governmental policy development, advising the Company or communicating the Company’s positions on various public policy and political issues that concern the business interests of the Company.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9493272
# --------------------------------------------------
#
# Sentence number: 45
# Sentence: We also began exploring new finishing methods in materials manufacturing that could potentially cut energy and water use in half and significantly reduce emissions, with an aim to pilot this technology at a manufacturing facility in FY22.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.98803085
# --------------------------------------------------
#
# Sentence number: 46
# Sentence: Onsite food, catering services and custodial services create the most waste at our headquarter campuses.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9876266
# --------------------------------------------------
#
# Sentence number: 47
# Sentence: This tactic yielded real results when reducing freshwater use and mitigating water risk.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9866447
# --------------------------------------------------
#
# Sentence number: 48
# Sentence: For footwear, we are focused on improving specific, high-volume materials (polyester, rubber and leather), particularly through significant increases in the use of recycled versions and the necessary integrated business strategies.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.96909654
# --------------------------------------------------
#
# Sentence number: 49
# Sentence: NIKE Footwear aims to achieve our 2025 goal of 10% recycled rubber through greater use, by leveraging higher-percentage recycled rubber content per pair
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9801292
# --------------------------------------------------
#
# Sentence number: 50
# Sentence: The Company believes that compensation for non-employee directors should be competitive and should encourage increased ownership of the Company's stock through the payment of a portion of director compensation in Company stock.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.99389666
# --------------------------------------------------
#
# Sentence number: 51
# Sentence: That’s why we are integrating chemistry selection deep into our product creation pipeline.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.45762995
# --------------------------------------------------
#
# Sentence number: 52
# Sentence: When we have office space growth, or renovations, we are incorporating electrification and energy-efficient design to decarbonize and reduce energy usage.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9960328
# --------------------------------------------------
#
# Sentence number: 53
# Sentence: We will use data and insights to steer our investments to reach those children who are moving least.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.706311
# --------------------------------------------------
#
# Sentence number: 54
# Sentence: Directors are expected to attend meetings of the Board and committees on which he or she sits as well as the Company’s annual shareholder meeting, either in person or by means of remote communication.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9951605
# --------------------------------------------------
#
# Sentence number: 55
# Sentence: DMFa is regulated and on the RSL but the regulated limit does not disallow for its use.
# Manual label: Product Liability
# FinBERT label: Non-ESG
# FinBERT score:  0.9460022
# --------------------------------------------------
#
# Sentence number: 56
# Sentence: Any contributions by the NIKE Political Action Committee shall comply with all applicable laws, including required disclosures, and shall be approved by the board of directors of the Committee.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.69889194
# --------------------------------------------------
#
# Sentence number: 57
# Sentence: We saw a decrease in Tier 1 footwear operational waste per pair driven by continued scaling of our targeted phylon midsole defect tracking and reduction program.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.98857725
# --------------------------------------------------
#
# Sentence number: 58
# Sentence: Cotton use in NIKE Apparel is growing due to our focus on sport lifestyle product and T-shirts and we have long supported a 10% blending strategy for organic cotton.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.8052437
# --------------------------------------------------
#
# Sentence number: 59
# Sentence: This 16 p.p. difference is a direct result of vendors struggling to treat their wastewater so they can achieve the foundational limits of the conventional parameters listed in the ZDHC Wastewater Guidelines.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.97724867
# --------------------------------------------------
#
# Sentence number: 60
# Sentence: A more sustainable and circular future requires designing waste out of products from the start, optimizing manufacturing processes for maximum material efficiency, and then managing manufacturing material, end-of-life product and packaging via circular systems to preserve, recover, renew and regenerate its physical utility and economic value for society and the planet – now and for future generations.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.98931915
# --------------------------------------------------
#
# Sentence number: 61
# Sentence: Four suppliers failed due to using a chemical that NIKE had already phased-out of production.
# Manual label: Product Liability
# FinBERT label: Pollution & Waste
# FinBERT score:  0.8835542
# --------------------------------------------------
#
# Sentence number: 62
# Sentence: By the end of FY20, all in-scope suppliers completed water risk mitigation plans.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.98885393
# --------------------------------------------------
#
# Sentence number: 63
# Sentence: While our first aim is to reduce waste in the footwear creation process, we also want to create opportunities for reinserting the waste we create back into footwear product.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.99084115
# --------------------------------------------------
#
# Sentence number: 64
# Sentence: As a company, Nike does not make charitable or political contributions or payments to political candidates or causes, except as specifically permitted by law and authorized by company policy.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.63607514
# --------------------------------------------------
#
# Sentence number: 65
# Sentence: NIKE Directrevenues increased 37%, driven by strong digital sales growth of 73%, comparable store sales growth of 5% and the addition of new stores.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9941729
# --------------------------------------------------
#
# Sentence number: 66
# Sentence: We identified the key waste streams by mass and overall impact and are concentrating our efforts on the biggest areas of opportunity.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9904405
# --------------------------------------------------
#
# Sentence number: 67
# Sentence: With the Institution of Occupational Safety and Health (IOSH), we have successfully piloted an enterprise-level program with our largest supplier groups to help their company leaders evaluate and improve the effectiveness of existing safety governance structure and safety leadership.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9911117
# --------------------------------------------------
#
# Sentence number: 68
# Sentence: While suppliers are making significant emissions reductions through deployment of onsite solar PV, facilitating access to offsite renewable electricity through mechanisms like PPAs will offer even greater opportunities for suppliers to reduce their emissions footprint.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.99491197
# --------------------------------------------------
#
# Sentence number: 69
# Sentence: Our well-being strategy is focused on supporting employees’ physical, emotional and financial well-being, with bespoke benefit initiatives and programs for each area.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9930227
# --------------------------------------------------
#
# Sentence number: 70
# Sentence: We compete fairly and comply with all applicable antitrust and competition laws in the countries where we operate.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9536238
# --------------------------------------------------
#
# Sentence number: 71
# Sentence: The NIKE Brand, which represents over 90% of NIKE, Inc. Revenues, experiencedgrowth of 19%, up 17% on a currency-neutral basis, driven by increases across all geographies
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9924089
# --------------------------------------------------
#
# Sentence number: 72
# Sentence: This process then informs GRM’s audit and risk plan and how GRM deploys risk management services across NIKE, Inc.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9768891
# --------------------------------------------------
#
# Sentence number: 73
# Sentence: Last year, Converse increased its grant funding by six times and expanded to 27 community partnerships in Boston, London, Los Angeles and New York City.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9854961
# --------------------------------------------------
#
# Sentence number: 74
# Sentence: We also continued scaling a program to ship certain input materials to suppliers in reusable boxes instead of single-use cartons.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9590884
# --------------------------------------------------
#
# Sentence number: 75
# Sentence: Finished goods and materials suppliers account for approximately 30% of NIKE’s total emissions footprint.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9786401
# --------------------------------------------------
#
# Sentence number: 76
# Sentence: Over 80% of the individuals served by Converse’s programming were from Black and Brown communities.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.98875266
# --------------------------------------------------
#
# Sentence number: 77
# Sentence: More than 1,600 employees from six countries participated in the compensation sessions, and 95% said they would recommend the session to others.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9932481
# --------------------------------------------------
#
# Sentence number: 78
# Sentence: During fiscal 2021, the transaction with Grupo SBF S.A. to purchase substantially all of our NIKE Brand operations in Brazil closed.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9931144
# --------------------------------------------------
#
# Sentence number: 79
# Sentence: The Compensation Committee also plays a significant role in the People pillar by overseeing talent management and development for executive officers and senior management, including with respect to employee engagement and workplace diversity and inclusion.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9703062
# --------------------------------------------------
#
# Sentence number: 80
# Sentence: We team up with grassroots organizations, business relationships, and employees to help kids – especially those who face the steepest barriers – realize their potential through play and sport.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.96684796
# --------------------------------------------------
#
# Sentence number: 81
# Sentence: NIKE’s corporate governance reflects the company’s commitment to monitor the effectiveness of policy and decision-making both at the Board of Directors and executive level.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.99375254
# --------------------------------------------------
#
# Sentence number: 82
# Sentence: Operating overhead expense increased primarily due to an increase in strategic technology investments, higher NIKE Direct variable costs and $255 million inrestructuring-related costs, partially offset by lower bad debt expense and travel and related expenses.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.99395895
# --------------------------------------------------
#
# Sentence number: 83
# Sentence: Since starting the program in FY18, 97 machine safety practitioners have completed the Pilz training course, with 56 people designated as Certified Machine Safety Experts.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9935215
# --------------------------------------------------
#
# Sentence number: 84
# Sentence: NIKE GRM reports administratively to the Chief Financial Officer and functionally to the Audit & Finance Committee.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.994354
# --------------------------------------------------
#
# Sentence number: 85
# Sentence: Further, our chemistry experts go beyond simple hazard identification when evaluating chemicals.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.9298685
# --------------------------------------------------
#
# Sentence number: 86
# Sentence: On a currency-neutral basis, North America revenues increased 19%, driven by growth in nearly all key categories, led by Sportswear and the Jordan Brand.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.99360836
# --------------------------------------------------
#
# Sentence number: 87
# Sentence: This Code of Conduct applies to everyone, at every level, across our team.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9844354
# --------------------------------------------------
#
# Sentence number: 88
# Sentence: NIKE’s commitment to purpose begins at the highest level with our Board of Directors (Board)
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9946425
# --------------------------------------------------
#
# Sentence number: 89
# Sentence: The Nike Code of Conduct provides an overview of the laws, regulations and company policies that apply to us and the work we do, but it does more than that.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9859364
# --------------------------------------------------
#
# Sentence number: 90
# Sentence: The process is also adaptable so when we identify new attributes or proposed regulations we can quickly determine if any of the chemicals we’ve evaluated previously present a risk to the brand from their use.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.906314
# --------------------------------------------------
#
# Sentence number: 91
# Sentence: In the absence of a Lead Independent Director, the responsibility to preside as chair of the executive sessions or meetings is rotated among the chairs of the Board committees as designated by the Corporate Responsibility, Sustainability & Governance Committee.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.99556077
# --------------------------------------------------
#
# Sentence number: 92
# Sentence: Our phase-out of PFCs remains on track to meet our goal by the end of 2021, and the availability of approved clean chemistry alternatives for PFC containing DWR continues to grow.
# Manual label: Product Liability
# FinBERT label: Climate Change
# FinBERT score:  0.602001
# --------------------------------------------------
#
# Sentence number: 93
# Sentence: NIKE’s long history of community investment in its primary markets and sourcing backyards has resulted in giving millions of kids the opportunity to realize the multi-dimensional benefits of play and sport, ranging from better physical and mental health, higher educational outcomes and overall success in life.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.98970604
# --------------------------------------------------
#
# Sentence number: 94
# Sentence: Purpose leadership begins with our Chief Executive Officer and Executive Leadership Team, who set the tone and ensure it is integrated into NIKE’s business strategy.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9941035
# --------------------------------------------------
#
# Sentence number: 95
# Sentence: In addition, we feature organic cotton as a primary fabric content in key products such as our Kids/Girls NIKE Sportswear Jerseys made with at least 50% organic cotton.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.770318
# --------------------------------------------------
#
# Sentence number: 96
# Sentence: The Ningbo Shenzhou Knitting Company, Ltd., reduced its freshwater use in FY21 by 13.9% (FY16–FY20: 39%); and its sister facility – Gain Lucky – in Vietnam reduced its use by 8.6% (FY16–FY20: 9.7%).
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9789868
# --------------------------------------------------
#
# Sentence number: 97
# Sentence: We utilized over 27 million of the improved fit shoe cartons in FY21, resulting in a reduction of 735,000 kg of corrugate waste shipped from suppliers in the first year of the transition.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.99096197
# --------------------------------------------------
#
# Sentence number: 98
# Sentence: These three facilities represent approximately 35% of the materials production for the in-scope suppliers for our 2025 water reduction target.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9767237
# --------------------------------------------------
#
# Sentence number: 99
# Sentence: At its core, NIKE’s Restricted Substances List (RSL) is a list of restricted chemicals, with limits on specific chemical substances
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.952094
# --------------------------------------------------
#
# Sentence number: 100
# Sentence: We do this by adopting, refining and standardizing industry-leading safety management systems and rules and by developing education, training and certification programs, and safety leadership capabilities.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9906313
# --------------------------------------------------
#
# Sentence number: 101
# Sentence: During FY21, we deployed NIKE’s Energy Minimum Program, which is an energy management foundation geared at achieving energy and cost savings.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.995891
# --------------------------------------------------
#
# Sentence number: 102
# Sentence: Until the second half of FY20, the MRSL successfully influenced chemical selection across the textile apparel industry, but the mid-FY20 launch of MRSL version 2.0 saw this important tool broaden its focus and further direct the sourcing of chemistry used to process and manufacture a wider array of footwear materials.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.5624339
# --------------------------------------------------
#
# Sentence number: 103
# Sentence: As part of this succession planning process, the Corporate Responsibility, Sustainability & Governance Committee considers the tenure of the current directors, the mix of skills, expertise and experiences on the Board and on each committee and the diversity of the directors.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9952662
# --------------------------------------------------
#
# Sentence number: 104
# Sentence: As Chief Ethics & Compliance Officer, I can’t overstate the importance of staying diligent in reporting any concerns or potential violations of the Code as soon as they arise – without exception.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9654388
# --------------------------------------------------
#
# Sentence number: 105
# Sentence: We will take all appropriate actions to prevent adverse consequences for raising a concern about potential misconduct or in cooperating with an investigation.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.94434637
# --------------------------------------------------
#
# Sentence number: 106
# Sentence: In its first year, the Family Grant Program supported 11 organizations across eight U.S. cities.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9862379
# --------------------------------------------------
#
# Sentence number: 107
# Sentence: We also began utilizing trucks to replace air freight while maintaining the same service level in digital order transportation, reducing 70% of carbon emission compared with air freight in FY21.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.99185467
# --------------------------------------------------
#
# Sentence number: 108
# Sentence: While bisphenol A has been restricted from use in many regions, often its replacement is another bisphenol that isn’t regulated yet.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.65670997
# --------------------------------------------------
#
# Sentence number: 109
# Sentence: Michael Jordan and the Jordan Brand also launched a second inaugural program, the Community Grant Program, with an open call to grassroots organizations to directly apply for grants to help advance local solutions and more equitable futures for Black Americans.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.98940665
# --------------------------------------------------
#
# Sentence number: 110
# Sentence: As our Executive Chairman, Mark Parker, said, this starts with the Maxims — our core values and beliefs that help anchor, inform and guide all that we do.
# Manual label: Business Ethics & Values
# FinBERT label: Corporate Governance
# FinBERT score:  0.73356766
# --------------------------------------------------
#
# Sentence number: 111
# Sentence: We require our employees and Board members to comply with the Code, and we expect those we do business with to share and observe these same values.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.94479746
# --------------------------------------------------
#
# Sentence number: 112
# Sentence: Listed below are direct cash political contributions made by NIKE, Inc. in calendar year 2021
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9200255
# --------------------------------------------------
#
# Sentence number: 113
# Sentence: It is the policy of the Board that the Board be comprised of a majority who qualify as independent directors under the listing standards of the New York Stock Exchange ("NYSE").
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9952082
# --------------------------------------------------
#
# Sentence number: 114
# Sentence: This approach is intended to allow us to create product that better meets individual consumer needs, including more specialization ofour category approach, while re-aligning and simplifying our offense to accelerate our largest growth opportunities.
# Manual label: Non-ESG
# FinBERT label: Product Liability
# FinBERT score:  0.6435079
# --------------------------------------------------
#
# Sentence number: 115
# Sentence: NIKE is uniquely positioned to focus our community investments to address the global crisis of physical inactivity in kids and make in
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9862227
# --------------------------------------------------
#
# Sentence number: 116
# Sentence: With a strategy based on creating awareness, driving commitment, and building capabilities within our supply chain, we hit our FY20 water reduction target 18 months early
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9815522
# --------------------------------------------------
#
# Sentence number: 117
# Sentence: In FY21, the NIKE water program was recognized by the Brave Blue World Foundation as a global leader and industry role model for driving water sustainability in the footwear/apparel supply chain.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.98228467
# --------------------------------------------------
#
# Sentence number: 118
# Sentence: These investments have helped to drive significant, positive change for kids and communities around the world.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.98915815
# --------------------------------------------------
#
# Sentence number: 119
# Sentence: In partnership with NIKE’s Responsible Sourcing and Manufacturing teams, we also piloted the industry-leading Social Labor Convergence Program’s (SLCP) EHS self-assessment module and verification at select global logistics operations.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9865812
# --------------------------------------------------
#
# Sentence number: 120
# Sentence: By the end of FY20, freshwater use was 119 liters per kilogram, a 42% reduction from the baseline.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.98023945
# --------------------------------------------------
#
# Sentence number: 121
# Sentence: The SSC is a group of 11 strategic suppliers committed to innovating and scaling sustainability programs to enhance their operational performance and mitigate risk while sharing out best practices in the hopes of elevating worker safety across the sector.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9947973
# --------------------------------------------------
#
# Sentence number: 122
# Sentence: Avoid any actions that are at odds, or could appear to be at odds, with the interests of Nike
# Manual label: Business Ethics & Values
# FinBERT label: Corporate Governance
# FinBERT score:  0.78334236
# --------------------------------------------------
#
# Sentence number: 123
# Sentence: In 2016, we signed the White House Equal Pay Pledge and have developed an ongoing discipline of reviewing our pay practices annually to achieve and maintain pay equity for our approximately 75,000 teammates across all geographies, functions and business units.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.8964878
# --------------------------------------------------
#
# Sentence number: 124
# Sentence: In fiscal 2021, NIKE, Inc. achieved record Revenues which increased 19% to $44.5 billion.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9920021
# --------------------------------------------------
#
# Sentence number: 125
# Sentence: As a result, all 13 at-risk facilities that were determined to be high risk have now implemented water-risk mitigation plans.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.98507696
# --------------------------------------------------
#
# Sentence number: 126
# Sentence: We bring it to life through our Code of Conduct — our roadmap that we expect NIKE, Inc. employees to follow to comply with laws and ethical practices.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9831904
# --------------------------------------------------
#
# Sentence number: 127
# Sentence: Since fiscal 2018, through the Consumer Direct Offense and our Triple Double strategy, we have focused on doubling the impact of innovation, increasing our speed and agilityto market and growing our direct connections with consumers.
# Manual label: Non-ESG
# FinBERT label: Product Liability
# FinBERT score:  0.89989156
# --------------------------------------------------
#
# Sentence number: 128
# Sentence: Our cleaner chemistry work begins with our foundational requirements set forth in the Code, requiring all suppliers to properly manage chemistry and create approaches to meet our Restricted Substances List (RSL) and MRSL requirements.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.8903816
# --------------------------------------------------
#
# Sentence number: 129
# Sentence: The majority of NIKE’s packaging in footwear is produced with over 90% recycled content.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.988187
# --------------------------------------------------
#
# Sentence number: 130
# Sentence: Multiple projects have been initiated to achieve our goal of reduced packaging.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.98070085
# --------------------------------------------------
#
# Sentence number: 131
# Sentence: From this relationship, NIKE developed a workplace safety facilitator program to develop soft skills so workers, managers and leaders can deliver peer-to-peer safety conversations on fire safety as well as other safety topics.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.99557674
# --------------------------------------------------
#
# Sentence number: 132
# Sentence: Our strategy goes beyond phase-out of PFCs but includes ensuring that we replace them with clean-chemistry alternatives, which demonstrates our ability to drive the adoption of better chemistry and maintain outstanding performance
# Manual label: Product Liability
# FinBERT label: Pollution & Waste
# FinBERT score:  0.72532445
# --------------------------------------------------
#
# Sentence number: 133
# Sentence: In FY21, NIKE launched onsite solar programs in Vietnam and Indonesia, and suppliers added significant onsite solar PV capacity, with 25 facilities signing contracts for 32 MW of solar energy.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.995507
# --------------------------------------------------
#
# Sentence number: 134
# Sentence: Selecting and creating cleaner chemistry materials leads to benefits in our health, our planet and our future.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.5418954
# --------------------------------------------------
#
# Sentence number: 135
# Sentence: Community investments also drive NIKE, Inc.’s commitment to leveling the playing field for all, so that nothing gets in the way of kids and communities realizing their full potential.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9890085
# --------------------------------------------------
#
# Sentence number: 136
# Sentence: As online sales have grown, we expected corrugated cardboard waste to similarly increase due to needing to repack factory case sizes to smaller e-commerce order sizes, but it did not.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9906275
# --------------------------------------------------
#
# Sentence number: 137
# ...
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.95053077
# --------------------------------------------------
#
# Sentence number: 191
# Sentence: We are leveraging the momentum created in our supply chain during the FY20 target period that enabled us to achieve a 30% freshwater reduction to now commit to a FY25 water reduction target (on a liters per kilogram basis) of 25% from our FY20 baseline across our strategic materials vendors.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9852991
# --------------------------------------------------
#
# Sentence number: 192
# Sentence: Throughout our phaseout, we have made a point of completing a toxicology assessment on all PFC alternatives to help enable better chemistry to be substituted into the supply chain.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.6353556
# --------------------------------------------------
#
# Sentence number: 193
# Sentence: Finally, our EMEA distribution center closed the loop on being 100% plastic free for all digital and B2B packaging deliveries.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.97835207
# --------------------------------------------------
#
# Sentence number: 194
# Sentence: We are concentrating conversions to recycled polyester, organic cotton and recycled cotton content on key highvolume fabrics and products.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9309425
# --------------------------------------------------
#
# Sentence number: 195
# Sentence: When we detect a chemical that exceeds our RSL standard, we work directly with our suppliers to increase chemical management capabilities and remediate the issue, ultimately creating a more capable supply chain.
# Manual label: Product Liability
# FinBERT label: Pollution & Waste
# FinBERT score:  0.720794
# --------------------------------------------------
#
# Sentence number: 196
# Sentence: The project will significantly reduce NIKE’s overall water footprint, as well as the ease the impact on supplies at a local level.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.98899466
# --------------------------------------------------
#
# Sentence number: 197
# Sentence: This puts NIKE among the top users of this key sustainable fiber globally
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.41324225
# --------------------------------------------------
#
# Sentence number: 198
# Sentence: We have seen great progress with Scope 2 emissions, driven by renewable electricity through PPAs, vPPAs and onsite renewable energy
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.99591917
# --------------------------------------------------
#
# Sentence number: 199
# Sentence: Income (loss) before income taxes increased 131% for fiscal 2021, primarily due to higher revenues, gross margin expansion and selling and administrative expense leverage.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.99343735
# --------------------------------------------------
#
# Sentence number: 200
# Sentence: As the needs of our communities became clear last year, NIKE responded by investing more than ever before.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9884099
# --------------------------------------------------
#
# Sentence number: 201
# Sentence: NIKE requires Tier 1 and strategic Tier 2 suppliers to adopt fire prevention and emergency action plans for the protection of workers during normal working operations and emergency situations.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9946346
# --------------------------------------------------
#
# Sentence number: 202
# Sentence: In recent years, the Board has had 10 – 14 directors, and it is the belief of the Board that this size permits diversity of experience without hindering effective discussion or diminishing individual accountability.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9937888
# --------------------------------------------------
#
# Sentence number: 203
# Sentence: Over the past five years, we’ve consistently outperformed our goal of investing a minimum of 1.5% of prioryear pre-tax income to impact communities around the world.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9880938
# --------------------------------------------------
#
# Sentence number: 204
# Sentence: These investments will aim to create impact at the intersection of race, gender, and orientation, and in turn, create opportunities and spaces for people to unite through the power of sport.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9354227
# --------------------------------------------------
#
# Sentence number: 205
# Sentence: Historically, carbon emissions from outbound transportation (from a NIKE distribution center to final destination, including to the consumer) have been challenging with the growth of e-commerce sales, as we try to balance speed and carbon emissions.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9942392
# --------------------------------------------------
#
# Sentence number: 206
# Sentence: During FY21, we raised our minimum hourly rate to $15 for retail store teammates in North America and increased our hourly rates for store employees across EMEA.2
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.98555785
# --------------------------------------------------
#
# Sentence number: 207
# Sentence: Whether it’s manufacturing protective equipment for healthcare workers or providing financial relief after devastating wildfires, we’re there to support our employees and the communities they call home.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.68053895
# --------------------------------------------------
#
# Sentence number: 208
# Sentence: Each year, we will provide grants to nonprofits working to level the playing field for the communities represented by our eight NIKE Employee Networks (NikeUNITED).
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.99065125
# --------------------------------------------------
#
# Sentence number: 209
# Sentence: During fiscal 2020, we entered into definitive agreements to sell our NIKE Brand businesses in Brazil, Argentina, Chile and Uruguay and to shift to a distributor operatingmodel.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9929744
# --------------------------------------------------
#
# Sentence number: 210
# Sentence: We remain committed to effectively managing our business and mitigating financial market risks to achieve our financial goals over the long-term byexecuting against the operational strategies outlined above.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.90251356
# --------------------------------------------------
#
# Sentence number: 211
# Sentence: This strategy will lead with NIKE Digital and our owned stores, as well asthrough select strategic partners who share our marketplace vision.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.72238094
# --------------------------------------------------
#
# Sentence number: 212
# Sentence: Under a business-as-usual scenario, NIKE expects emissions from manufacturing to increase by more than 30% over the next five years – which means that, to reduce absolute emissions during this time, we need to push beyond incremental reductions and unlock transformative solutions.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.99137104
# --------------------------------------------------
#
# Sentence number: 213
# Sentence: We achieved our water risk targets and significantly exceeded our water reduction target by engaging with our suppliers to create awareness, drive commitment, and build capability.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9883994
# --------------------------------------------------
#
# Sentence number: 214
# Sentence: In this context, NIKE approaches governance with a view to enhancing long-term shareholder value.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.98087615
# --------------------------------------------------
#
# Sentence number: 215
# Sentence: Each year, we elevate the expectations of our supply chain to meet more stringent RSL standards, including expanded substances, lowering specific limits or new chemical bans.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.94293
# --------------------------------------------------
#
# Sentence number: 216
# Sentence: Innovation will be increasingly important, focusing on new recycling methods and material types that meet our product and consumer requirements.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.97836477
# --------------------------------------------------
#
# Sentence number: 217
# Sentence: Our programs help to drive operational efficiencies and energy savings among our supply chain while also building operational resilience for a future where climate impacts are the norm.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.99586284
# --------------------------------------------------
#
# Sentence number: 218
# Sentence: We know that materials account for approximately 70% of NIKE’s product carbon footprint
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9941016
# --------------------------------------------------
#
# Sentence number: 219
# Sentence: Demand creation expense decreased primarily due to lower marketing and advertising expenses for our brand events and retailoperations, as well as lower sports marketing expenses as sporting events were postponed due to COVID-19.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9929356
# --------------------------------------------------
#
# Sentence number: 220
# Sentence: Since FY16, our vendors have avoided using a cumulative 40 billion liters of freshwater – 12 billion from NIKE’s freshwater footprint, the rest from other brands, including our competitors, who source from the same suppliers.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.96768326
# --------------------------------------------------
#
# Sentence number: 221
# Sentence: However, we expect the future operating model to have a favorable impact on our overallprofitability as we reduce selling and administrative expenses, as well as lessen exposure to foreign exchange rate volatility.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.99063265
# --------------------------------------------------
#
# Sentence number: 222
# Sentence: NIKE required suppliers to assess water-related risks, such as flooding and drought, and develop mitigation plans.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.98716855
# --------------------------------------------------
#
# Sentence number: 223
# Sentence: Specifically, through collaboration and engagement, sportswear multinational NIKE has encouraged its suppliers to explore ways of reducing water used in their manufacturing processes.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.97053075
# --------------------------------------------------
#
# Sentence number: 224
# Sentence: In June 2020, we announced a new digitally empowered phase of the Consumer Direct Offense strategy:Consumer Direct Acceleration.
# Manual label: Non-ESG
# FinBERT label: Product Liability
# FinBERT score:  0.85387224
# --------------------------------------------------
#
# Sentence number: 225
# Sentence: And the Board of Directors continues to actively oversee the company’s purpose, because we know that strong governance supports and enhances NIKE’s capacity to make progress.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.99447894
# --------------------------------------------------
#      No.                                           Sentence Label  \
# 0      1  Importantly, our measure of MRSL compliance is...    PL
# 1      2  It assists NIKE, Inc. in accomplishing its obj...    CG
# 2      3  Internally, our Women of Nike & Friends Networ...    HC
# 3      4  In Belgium, at our Converse European Logistics...    CC
# 4      5  The Company will not make political contributi...    BE
# ..   ...                                                ...   ...
# 220  221  However, we expect the future operating model ...     N
# 221  222  NIKE required suppliers to assess water-relate...    NC
# 222  223  Specifically, through collaboration and engage...    NC
# 223  224  In June 2020, we announced a new digitally emp...     N
# 224  225  And the Board of Directors continues to active...    CG
#
#     FinBERT label  FinBERT score  Correct label  Climate Change  \
# 0              PL       0.781741              1        0.005837
# 1              CG       0.976031              1        0.001785
# 2              HC       0.811219              1        0.002511
# 3              CC       0.995495              1        0.995495
# 4              BE       0.968667              1        0.001151
# ..            ...            ...            ...             ...
# 220             N       0.990633              1        0.000611
# 221            NC       0.987169              1        0.003108
# 222            NC       0.970531              1        0.002104
# 223            PL       0.853872              0        0.029915
# 224            CG       0.994479              1        0.000488
#
#      Natural Capital  Pollution & Waste  Human Capital  Product Liability  \
# 0           0.008719           0.018283       0.108884           0.781741
# 1           0.000750           0.000673       0.002529           0.002088
# 2           0.001111           0.001281       0.811219           0.017498
# 3           0.000916           0.001224       0.000271           0.000408
# 4           0.001800           0.001200       0.003276           0.001506
# ..               ...                ...            ...                ...
# 220         0.000397           0.000871       0.000824           0.001539
# 221         0.987169           0.003630       0.000524           0.001987
# 222         0.970531           0.017974       0.000855           0.004111
# 223         0.006763           0.004608       0.007451           0.853872
# 224         0.000349           0.000394       0.000721           0.000240
#
#      Community Relations  Corporate Governance  Business Ethics & Values  \
# 0               0.001808              0.027980                  0.042614
# 1               0.000599              0.976031                  0.006527
# 2               0.126240              0.009988                  0.017754
# 3               0.000422              0.000548                  0.000280
# 4               0.002203              0.016750                  0.968667
# ..                   ...                   ...                       ...
# 220             0.000979              0.003462                  0.000684
# 221             0.001856              0.000600                  0.000832
# 222             0.001953              0.000774                  0.001352
# 223             0.037358              0.007024                  0.048121
# 224             0.000402              0.994479                  0.002319
#
#       Non-ESG
# 0    0.004134
# 1    0.009018
# 2    0.012397
# 3    0.000436
# 4    0.003447
# ..        ...
# 220  0.990633
# 221  0.000296
# 222  0.000346
# 223  0.004888
# 224  0.000609
#
# [225 rows x 15 columns]

# %% [markdown]
# ### 2.2. OPTION 2: Only Output Predicted Label

# %%
# use pipeline in transformers to assemble the steps of finbert prediction
if torch.cuda.is_available(): # has GPU
  nlp = pipeline("text-classification", model = finbert, tokenizer = tokenizer, device = 0)
else: # CPU only
  nlp = pipeline("text-classification", model = finbert, tokenizer = tokenizer)


# demonstrate the output
print('nlp output: ', nlp('For 2002, our total net emissions were approximately 60 million metric tons of CO2 equivalents for all businesses and operations we have ﬁnancial interests in, based on its equity share in those businesses and operations.'))
# Out:
# nlp output:  [{'label': 'Climate Change', 'score': 0.9955655932426453}]

# %%
# Process sample data and download predicted label

# define the output structure
header = ['No.', 'Sentence', 'Label', 'FinBERT label', 'FinBERT score', 'Correct label']
result = []

# loop through the sentences
for i, row in data.iterrows():

  # sentence number
  id = str(i+1)
  print('Sentence number: ' + id)

  # sentence
  sentence = row['Sentence']
  print('Sentence: ' + sentence)

  # use the nlp function to process the sentence, get finbert label and score
  finbert_output = nlp(sentence)[0]

  # label and score
  manual_label = row['Label']
  finbert_label = label_map[finbert_output['label']]
  finbert_score = finbert_output['score']
  print('Manual label: ' + label_map_reverse[manual_label])
  print('FinBERT label: ' + finbert_output['label'])
  print('FinBERT score: ', finbert_score)

  print('-'*50)
  print()

  # combine all the output above into one row of observation
  row = [id, sentence, manual_label, finbert_label, finbert_score, 1*(manual_label==finbert_label)]
  result.append(row)

# consolidate the output into a dataframe
result_df_label = pd.DataFrame(result, columns = header)

# save the output in the csv format
result_df_label.to_csv('FinBERT ESG9Class output label.csv', index = False)
# download the output to the local computer
from google.colab import files
files.download('FinBERT ESG9Class output label.csv')
# display the output
result_df_label
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Sentence number: 1
# Sentence: Importantly, our measure of MRSL compliance is based at the facility level and not solely on NIKE production.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.7817407250404358
# --------------------------------------------------
#
# Sentence number: 2
# Sentence: It assists NIKE, Inc. in accomplishing its objectives by partnering with management to build and maintain effective risk management, control and governance processes.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.976030707359314
# --------------------------------------------------
#
# Sentence number: 3
# Sentence: Internally, our Women of Nike & Friends Network – through NikeUNITED – continues to play a significant role in retention and promotion of women through its robust, interactive programming.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.8112188577651978
# --------------------------------------------------
#
# Sentence number: 4
# Sentence: In Belgium, at our Converse European Logistics Campus, a rooftop solar array also went live and is estimated to produce 3,000 MWh annually, covering a significant portion of the facility’s electricity needs.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.995495080947876
# --------------------------------------------------
#
# Sentence number: 5
# Sentence: The Company will not make political contributions related to a U.S. federal election, including candidates, political parties or political action committees.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9686669111251831
# --------------------------------------------------
#
# Sentence number: 6
# Sentence: For Compensation Committee members, the Board must consider all factors specifically relevant to determining whether a director has a relationship to the Company that is material to the ability to be independent from management in connection with the duties of a Compensation Committee member, including the source of compensation of the director, any consulting, advisory or other compensatory fee paid by the Company to the director; and whether the director is affiliated with the Company or any subsidiary.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9957355260848999
# --------------------------------------------------
#
# Sentence number: 7
# Sentence: This includes a $40 million commitment over the next four years to invest in and support organizations focused on economic empowerment to address racial inequality for the Black community
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9808413982391357
# --------------------------------------------------
#
# Sentence number: 8
# Sentence: As gender inequality in the workplace remains a pervasive global issue, we strive to enable women to reach their full career potential while staying committed to fostering an environment that supports them in the workplace.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9943296909332275
# --------------------------------------------------
#
# Sentence number: 9
# Sentence: We do not offer, promise, give or accept money or anything of value to or from third parties to get an improper business advantage.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9623543620109558
# --------------------------------------------------
#
# Sentence number: 10
# Sentence: The Board will meet at least four times per year.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9942482709884644
# --------------------------------------------------
#
# Sentence number: 11
# Sentence: Through FY21, our creation-led waste target was behind plan
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9862449765205383
# --------------------------------------------------
#
# Sentence number: 12
# Sentence: Nike takes all allegations of misconduct or other wrongdoing seriously and will investigate them thoroughly
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9706793427467346
# --------------------------------------------------
#
# Sentence number: 13
# Sentence: Effective corporate management and oversight of Occupational Safety & Health (OS&H) implementation at the highest level of an organization enables more effective and sustained health and safety programs and performance.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9930921792984009
# --------------------------------------------------
#
# Sentence number: 14
# Sentence: For employees who continued to work from home due to COVID-19 health and safety measures, we provided them with select technology and ergonomic products through a partnership with Staples
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9939318895339966
# --------------------------------------------------
#
# Sentence number: 15
# Sentence: When we prioritize the well-being of our employees – inspiring and enabling everyone to deliver their best work – we bring our best as a team.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9942441582679749
# --------------------------------------------------
#
# Sentence number: 16
# Sentence: We continue to evolve and expand our standards and programs to drive improved outcomes for workers in our supply chain and communities where suppliers operate and enhanced value for NIKE and suppliers.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9929840564727783
# --------------------------------------------------
#
# Sentence number: 17
# Sentence: Reported EBIT increased 76% driven by higher revenues, lower selling and administrative expense as a percent of revenues and gross margin expansion.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9935553669929504
# --------------------------------------------------
#
# Sentence number: 18
# Sentence: In addition to this Policy, any and all political contributions must also comply with Company’s code of ethics, the Foreign Corrupt Practices Act and all other applicable laws and regulations in the jurisdictions in which the contributions will be made.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.986747145652771
# --------------------------------------------------
#
# Sentence number: 19
# Sentence: Hundreds of thousands of raw materials tests have been achieved since the program’s launch, generating millions of chemical data points that allow us to proactively control the chemical compliance of our products.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.8281806707382202
# --------------------------------------------------
#
# Sentence number: 20
# Sentence: Due to the substantial positive impact on our inbound carbon emissions (air freight is on average 42 times more carbon intensive than ocean freight), NIKE is working to not return to pre-pandemic air freight usage, through our Move to Zero air freight program.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9935777187347412
# --------------------------------------------------
#
# Sentence number: 21
# Sentence: Even with the spread of COVID-19 in the second half of FY20, our materials suppliers were able to maintain their water-efficiency gains, demonstrating that our efficiency initiatives have been operationalized and the water savings are real.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9846899509429932
# --------------------------------------------------
#
# Sentence number: 22
# Sentence: We know that some kids and communities face more barriers than others – whether that be accessing education, sport, or mentorship – so we invest in community organizations and programs that aim to remove barriers for all kids and communities.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9887635707855225
# --------------------------------------------------
#
# Sentence number: 23
# Sentence: We are obligated to report requests to comply with certain boycotts to the U.S. government
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.8991196155548096
# --------------------------------------------------
#
# Sentence number: 24
# Sentence: In FY21, we completed the LeBron James and Serena Williams buildings, both of which achieved LEED Platinum certification.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9792783260345459
# --------------------------------------------------
#
# Sentence number: 25
# Sentence: NIKE Global Risk Management (GRM) is an independent and objective audit and risk organization that is guided by a philosophy of enhancing and protecting NIKE, Inc.’s value and brand through world-class risk management capabilities.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9808169007301331
# --------------------------------------------------
#
# Sentence number: 26
# Sentence: We’re putting innovation resources toward the exploration of other leather alternatives from non-animal sources.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9388003349304199
# --------------------------------------------------
#
# Sentence number: 27
# Sentence: Considering all freshwater use (rather than just for dyeing and finishing), its FY16 baseline was 205 liters of freshwater per kilogram of dyed and finished fabric, making it one of the least efficient water users in the scope of this target
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9796571135520935
# --------------------------------------------------
#
# Sentence number: 28
# Sentence: We aim to move to high-recycled percentage formulations that maintain material benefits while lowering environmental impact.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.979401171207428
# --------------------------------------------------
#
# Sentence number: 29
# Sentence: At each Board meeting, the CRS&G Committee reports to the Board on purpose highlights and key developments.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9946961402893066
# --------------------------------------------------
#
# Sentence number: 30
# Sentence: NIKE is well ahead of our recycled polyester plan in both footwear and apparel.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9616555571556091
# --------------------------------------------------
#
# Sentence number: 31
# Sentence: NIKE Apparel’s goal is to increase efficiency in our product designs earlier in our creation and development process, which will reduce waste when those products are manufactured.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9896713495254517
# --------------------------------------------------
#
# Sentence number: 32
# Sentence: In Greater China, alternative transportation methods for outbound shipping have helped reduce carbon emissions.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9943966865539551
# --------------------------------------------------
#
# Sentence number: 33
# Sentence: Revenues for Converse increased 19% and 16%, on a reported and currencyneutral basis, respectively, led by strong double-digit growth in digital.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9938868880271912
# --------------------------------------------------
#
# Sentence number: 34
# Sentence: Investing in more equal, inclusive, and active communities isn’t just the right thing to do as a business, it’s also critical for helping to realize a thriving future for our kids, communities, and the planet.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9869452118873596
# --------------------------------------------------
#
# Sentence number: 35
# Sentence: During FY21, these suppliers completed all of the foundational requirements of the program, which includes having their science-based Scope 1 and 2 emission targets validated by the World Resources Institute (WRI).
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9914872646331787
# --------------------------------------------------
#
# Sentence number: 36
# Sentence: To help us achieve full RSL compliance, we aligned our RSL with guidelines established by the Apparel and Footwear International RSL Management (AFIRM) Group.
# Manual label: Product Liability
# FinBERT label: Corporate Governance
# FinBERT score:  0.9245650172233582
# --------------------------------------------------
#
# Sentence number: 37
# Sentence: It is expected that a director who is unable to attend a Board meeting, committee meeting or annual shareholder meeting (which, it is understood, will occur on occasion) will notify the Chair of the Board or the chair of the relevant committee.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.995323121547699
# --------------------------------------------------
#
# Sentence number: 38
# Sentence: In addition to following local government restrictions, the World Health Organization (WHO), and Centers for Disease Control and Prevention (CDC) requirements for protecting workers and preventing community spread, we are continually expanding fundamental capabilities on how to anticipate, recognize, evaluate, and control occupational health issues in the workplace.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9928919076919556
# --------------------------------------------------
#
# Sentence number: 39
# Sentence: For example, in India, we offered early payout of our Performance Share Plan to support immediate liquidity needs, we enhanced telemedicine and EAP access, and expanded EAP and telemedicine support for family members of our employees who reside in India.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9743772745132446
# --------------------------------------------------
#
# Sentence number: 40
# Sentence: NIKE, Inc. gross margin increased 140 basis points primarily due to annualizing the impacts of COVID-19 including lower factory cancellation charges, lower inventoryobsolescence reserves as well as the favorable rate impact of fixed supply chain costs on a higher volume of wholesale shipments.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.99381023645401
# --------------------------------------------------
#
# Sentence number: 41
# Sentence: To that end, it is the role of all managers who receive concerns of misconduct or violations of the Code from employees to report those allegations using an appropriate reporting channel, including the Speak Up Portal, Human Resources and the Ethics & Compliance Office.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9719147682189941
# --------------------------------------------------
#
# Sentence number: 42
# Sentence: At the same time, it is the policy of the Board that directors will not stand for re-election after reaching age 72.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9948647618293762
# --------------------------------------------------
#
# Sentence number: 43
# Sentence: While foreign currency markets remain volatile, in part due to geopolitical dynamics which may lead to a stronger U.S. Dollar, we continue to see opportunities to drive futuregrowth and profitability.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9906249642372131
# --------------------------------------------------
#
# Sentence number: 44
# Sentence: The Company may from time to time directly engage external registered lobbyists to assist the Company in monitoring governmental policy development, advising the Company or communicating the Company’s positions on various public policy and political issues that concern the business interests of the Company.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9493271708488464
# --------------------------------------------------
#
# Sentence number: 45
# Sentence: We also began exploring new finishing methods in materials manufacturing that could potentially cut energy and water use in half and significantly reduce emissions, with an aim to pilot this technology at a manufacturing facility in FY22.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9880308508872986
# --------------------------------------------------
#
# Sentence number: 46
# Sentence: Onsite food, catering services and custodial services create the most waste at our headquarter campuses.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9876266121864319
# --------------------------------------------------
#
# Sentence number: 47
# Sentence: This tactic yielded real results when reducing freshwater use and mitigating water risk.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9866446852684021
# --------------------------------------------------
#
# Sentence number: 48
# Sentence: For footwear, we are focused on improving specific, high-volume materials (polyester, rubber and leather), particularly through significant increases in the use of recycled versions and the necessary integrated business strategies.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9690965414047241
# --------------------------------------------------
#
# Sentence number: 49
# Sentence: NIKE Footwear aims to achieve our 2025 goal of 10% recycled rubber through greater use, by leveraging higher-percentage recycled rubber content per pair
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9801291823387146
# --------------------------------------------------
#
# Sentence number: 50
# Sentence: The Company believes that compensation for non-employee directors should be competitive and should encourage increased ownership of the Company's stock through the payment of a portion of director compensation in Company stock.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9938966631889343
# --------------------------------------------------
#
# Sentence number: 51
# Sentence: That’s why we are integrating chemistry selection deep into our product creation pipeline.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.4576299488544464
# --------------------------------------------------
#
# Sentence number: 52
# Sentence: When we have office space growth, or renovations, we are incorporating electrification and energy-efficient design to decarbonize and reduce energy usage.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9960327744483948
# --------------------------------------------------
#
# Sentence number: 53
# Sentence: We will use data and insights to steer our investments to reach those children who are moving least.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.7063109874725342
# --------------------------------------------------
#
# Sentence number: 54
# Sentence: Directors are expected to attend meetings of the Board and committees on which he or she sits as well as the Company’s annual shareholder meeting, either in person or by means of remote communication.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9951605200767517
# --------------------------------------------------
#
# Sentence number: 55
# Sentence: DMFa is regulated and on the RSL but the regulated limit does not disallow for its use.
# Manual label: Product Liability
# FinBERT label: Non-ESG
# FinBERT score:  0.946002185344696
# --------------------------------------------------
#
# Sentence number: 56
# Sentence: Any contributions by the NIKE Political Action Committee shall comply with all applicable laws, including required disclosures, and shall be approved by the board of directors of the Committee.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.6988919377326965
# --------------------------------------------------
#
# Sentence number: 57
# Sentence: We saw a decrease in Tier 1 footwear operational waste per pair driven by continued scaling of our targeted phylon midsole defect tracking and reduction program.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9885772466659546
# --------------------------------------------------
#
# Sentence number: 58
# Sentence: Cotton use in NIKE Apparel is growing due to our focus on sport lifestyle product and T-shirts and we have long supported a 10% blending strategy for organic cotton.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.8052436709403992
# --------------------------------------------------
#
# Sentence number: 59
# Sentence: This 16 p.p. difference is a direct result of vendors struggling to treat their wastewater so they can achieve the foundational limits of the conventional parameters listed in the ZDHC Wastewater Guidelines.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9772486686706543
# --------------------------------------------------
#
# Sentence number: 60
# Sentence: A more sustainable and circular future requires designing waste out of products from the start, optimizing manufacturing processes for maximum material efficiency, and then managing manufacturing material, end-of-life product and packaging via circular systems to preserve, recover, renew and regenerate its physical utility and economic value for society and the planet – now and for future generations.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9893191456794739
# --------------------------------------------------
#
# Sentence number: 61
# Sentence: Four suppliers failed due to using a chemical that NIKE had already phased-out of production.
# Manual label: Product Liability
# FinBERT label: Pollution & Waste
# FinBERT score:  0.883554220199585
# --------------------------------------------------
#
# Sentence number: 62
# Sentence: By the end of FY20, all in-scope suppliers completed water risk mitigation plans.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.988853931427002
# --------------------------------------------------
#
# Sentence number: 63
# Sentence: While our first aim is to reduce waste in the footwear creation process, we also want to create opportunities for reinserting the waste we create back into footwear product.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9908411502838135
# --------------------------------------------------
#
# Sentence number: 64
# Sentence: As a company, Nike does not make charitable or political contributions or payments to political candidates or causes, except as specifically permitted by law and authorized by company policy.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.6360751390457153
# --------------------------------------------------
#
# Sentence number: 65
# Sentence: NIKE Directrevenues increased 37%, driven by strong digital sales growth of 73%, comparable store sales growth of 5% and the addition of new stores.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9941728711128235
# --------------------------------------------------
#
# Sentence number: 66
# Sentence: We identified the key waste streams by mass and overall impact and are concentrating our efforts on the biggest areas of opportunity.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9904404878616333
# --------------------------------------------------
#
# Sentence number: 67
# Sentence: With the Institution of Occupational Safety and Health (IOSH), we have successfully piloted an enterprise-level program with our largest supplier groups to help their company leaders evaluate and improve the effectiveness of existing safety governance structure and safety leadership.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.991111695766449
# --------------------------------------------------
#
# Sentence number: 68
# Sentence: While suppliers are making significant emissions reductions through deployment of onsite solar PV, facilitating access to offsite renewable electricity through mechanisms like PPAs will offer even greater opportunities for suppliers to reduce their emissions footprint.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9949119687080383
# --------------------------------------------------
#
# Sentence number: 69
# Sentence: Our well-being strategy is focused on supporting employees’ physical, emotional and financial well-being, with bespoke benefit initiatives and programs for each area.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9930226802825928
# --------------------------------------------------
#
# Sentence number: 70
# Sentence: We compete fairly and comply with all applicable antitrust and competition laws in the countries where we operate.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9536237716674805
# --------------------------------------------------
#
# Sentence number: 71
# Sentence: The NIKE Brand, which represents over 90% of NIKE, Inc. Revenues, experiencedgrowth of 19%, up 17% on a currency-neutral basis, driven by increases across all geographies
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9924088716506958
# --------------------------------------------------
#
# Sentence number: 72
# Sentence: This process then informs GRM’s audit and risk plan and how GRM deploys risk management services across NIKE, Inc.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9768890738487244
# --------------------------------------------------
#
# Sentence number: 73
# Sentence: Last year, Converse increased its grant funding by six times and expanded to 27 community partnerships in Boston, London, Los Angeles and New York City.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9854961037635803
# --------------------------------------------------
#
# Sentence number: 74
# Sentence: We also continued scaling a program to ship certain input materials to suppliers in reusable boxes instead of single-use cartons.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9590883851051331
# --------------------------------------------------
#
# Sentence number: 75
# Sentence: Finished goods and materials suppliers account for approximately 30% of NIKE’s total emissions footprint.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.978640079498291
# --------------------------------------------------
#
# Sentence number: 76
# Sentence: Over 80% of the individuals served by Converse’s programming were from Black and Brown communities.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9887526631355286
# --------------------------------------------------
#
# Sentence number: 77
# Sentence: More than 1,600 employees from six countries participated in the compensation sessions, and 95% said they would recommend the session to others.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9932481050491333
# --------------------------------------------------
#
# Sentence number: 78
# Sentence: During fiscal 2021, the transaction with Grupo SBF S.A. to purchase substantially all of our NIKE Brand operations in Brazil closed.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9931144118309021
# --------------------------------------------------
#
# Sentence number: 79
# Sentence: The Compensation Committee also plays a significant role in the People pillar by overseeing talent management and development for executive officers and senior management, including with respect to employee engagement and workplace diversity and inclusion.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9703062176704407
# --------------------------------------------------
#
# Sentence number: 80
# Sentence: We team up with grassroots organizations, business relationships, and employees to help kids – especially those who face the steepest barriers – realize their potential through play and sport.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9668479561805725
# --------------------------------------------------
#
# Sentence number: 81
# Sentence: NIKE’s corporate governance reflects the company’s commitment to monitor the effectiveness of policy and decision-making both at the Board of Directors and executive level.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9937525391578674
# --------------------------------------------------
#
# Sentence number: 82
# Sentence: Operating overhead expense increased primarily due to an increase in strategic technology investments, higher NIKE Direct variable costs and $255 million inrestructuring-related costs, partially offset by lower bad debt expense and travel and related expenses.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9939589500427246
# --------------------------------------------------
#
# Sentence number: 83
# Sentence: Since starting the program in FY18, 97 machine safety practitioners have completed the Pilz training course, with 56 people designated as Certified Machine Safety Experts.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.993521511554718
# --------------------------------------------------
#
# Sentence number: 84
# Sentence: NIKE GRM reports administratively to the Chief Financial Officer and functionally to the Audit & Finance Committee.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9943540096282959
# --------------------------------------------------
#
# Sentence number: 85
# Sentence: Further, our chemistry experts go beyond simple hazard identification when evaluating chemicals.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.9298685193061829
# --------------------------------------------------
#
# Sentence number: 86
# Sentence: On a currency-neutral basis, North America revenues increased 19%, driven by growth in nearly all key categories, led by Sportswear and the Jordan Brand.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9936083555221558
# --------------------------------------------------
#
# Sentence number: 87
# Sentence: This Code of Conduct applies to everyone, at every level, across our team.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9844353795051575
# --------------------------------------------------
#
# Sentence number: 88
# Sentence: NIKE’s commitment to purpose begins at the highest level with our Board of Directors (Board)
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9946424961090088
# --------------------------------------------------
#
# Sentence number: 89
# Sentence: The Nike Code of Conduct provides an overview of the laws, regulations and company policies that apply to us and the work we do, but it does more than that.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9859364032745361
# --------------------------------------------------
#
# Sentence number: 90
# Sentence: The process is also adaptable so when we identify new attributes or proposed regulations we can quickly determine if any of the chemicals we’ve evaluated previously present a risk to the brand from their use.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.9063140153884888
# --------------------------------------------------
#
# Sentence number: 91
# Sentence: In the absence of a Lead Independent Director, the responsibility to preside as chair of the executive sessions or meetings is rotated among the chairs of the Board committees as designated by the Corporate Responsibility, Sustainability & Governance Committee.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9955607652664185
# --------------------------------------------------
#
# Sentence number: 92
# Sentence: Our phase-out of PFCs remains on track to meet our goal by the end of 2021, and the availability of approved clean chemistry alternatives for PFC containing DWR continues to grow.
# Manual label: Product Liability
# FinBERT label: Climate Change
# FinBERT score:  0.6020010113716125
# --------------------------------------------------
#
# Sentence number: 93
# Sentence: NIKE’s long history of community investment in its primary markets and sourcing backyards has resulted in giving millions of kids the opportunity to realize the multi-dimensional benefits of play and sport, ranging from better physical and mental health, higher educational outcomes and overall success in life.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9897060394287109
# --------------------------------------------------
#
# Sentence number: 94
# Sentence: Purpose leadership begins with our Chief Executive Officer and Executive Leadership Team, who set the tone and ensure it is integrated into NIKE’s business strategy.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9941034913063049
# --------------------------------------------------
#
# Sentence number: 95
# Sentence: In addition, we feature organic cotton as a primary fabric content in key products such as our Kids/Girls NIKE Sportswear Jerseys made with at least 50% organic cotton.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.7703179717063904
# --------------------------------------------------
#
# Sentence number: 96
# Sentence: The Ningbo Shenzhou Knitting Company, Ltd., reduced its freshwater use in FY21 by 13.9% (FY16–FY20: 39%); and its sister facility – Gain Lucky – in Vietnam reduced its use by 8.6% (FY16–FY20: 9.7%).
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9789867997169495
# --------------------------------------------------
#
# Sentence number: 97
# Sentence: We utilized over 27 million of the improved fit shoe cartons in FY21, resulting in a reduction of 735,000 kg of corrugate waste shipped from suppliers in the first year of the transition.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9909619688987732
# --------------------------------------------------
#
# Sentence number: 98
# Sentence: These three facilities represent approximately 35% of the materials production for the in-scope suppliers for our 2025 water reduction target.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9767236709594727
# --------------------------------------------------
#
# Sentence number: 99
# Sentence: At its core, NIKE’s Restricted Substances List (RSL) is a list of restricted chemicals, with limits on specific chemical substances
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.9520940184593201
# --------------------------------------------------
#
# Sentence number: 100
# Sentence: We do this by adopting, refining and standardizing industry-leading safety management systems and rules and by developing education, training and certification programs, and safety leadership capabilities.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9906312823295593
# --------------------------------------------------
#
# Sentence number: 101
# Sentence: During FY21, we deployed NIKE’s Energy Minimum Program, which is an energy management foundation geared at achieving energy and cost savings.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9958909749984741
# --------------------------------------------------
#
# Sentence number: 102
# Sentence: Until the second half of FY20, the MRSL successfully influenced chemical selection across the textile apparel industry, but the mid-FY20 launch of MRSL version 2.0 saw this important tool broaden its focus and further direct the sourcing of chemistry used to process and manufacture a wider array of footwear materials.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.5624338984489441
# --------------------------------------------------
#
# Sentence number: 103
# Sentence: As part of this succession planning process, the Corporate Responsibility, Sustainability & Governance Committee considers the tenure of the current directors, the mix of skills, expertise and experiences on the Board and on each committee and the diversity of the directors.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9952661991119385
# --------------------------------------------------
#
# Sentence number: 104
# Sentence: As Chief Ethics & Compliance Officer, I can’t overstate the importance of staying diligent in reporting any concerns or potential violations of the Code as soon as they arise – without exception.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9654387831687927
# --------------------------------------------------
#
# Sentence number: 105
# Sentence: We will take all appropriate actions to prevent adverse consequences for raising a concern about potential misconduct or in cooperating with an investigation.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9443463683128357
# --------------------------------------------------
#
# Sentence number: 106
# Sentence: In its first year, the Family Grant Program supported 11 organizations across eight U.S. cities.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9862378835678101
# --------------------------------------------------
#
# Sentence number: 107
# Sentence: We also began utilizing trucks to replace air freight while maintaining the same service level in digital order transportation, reducing 70% of carbon emission compared with air freight in FY21.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9918546676635742
# --------------------------------------------------
#
# Sentence number: 108
# Sentence: While bisphenol A has been restricted from use in many regions, often its replacement is another bisphenol that isn’t regulated yet.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.6567099690437317
# --------------------------------------------------
#
# Sentence number: 109
# Sentence: Michael Jordan and the Jordan Brand also launched a second inaugural program, the Community Grant Program, with an open call to grassroots organizations to directly apply for grants to help advance local solutions and more equitable futures for Black Americans.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9894066452980042
# --------------------------------------------------
#
# Sentence number: 110
# Sentence: As our Executive Chairman, Mark Parker, said, this starts with the Maxims — our core values and beliefs that help anchor, inform and guide all that we do.
# Manual label: Business Ethics & Values
# FinBERT label: Corporate Governance
# FinBERT score:  0.7335676550865173
# --------------------------------------------------
#
# Sentence number: 111
# Sentence: We require our employees and Board members to comply with the Code, and we expect those we do business with to share and observe these same values.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9447974562644958
# --------------------------------------------------
#
# Sentence number: 112
# Sentence: Listed below are direct cash political contributions made by NIKE, Inc. in calendar year 2021
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9200255274772644
# --------------------------------------------------
#
# Sentence number: 113
# Sentence: It is the policy of the Board that the Board be comprised of a majority who qualify as independent directors under the listing standards of the New York Stock Exchange ("NYSE").
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.995208203792572
# --------------------------------------------------
#
# Sentence number: 114
# Sentence: This approach is intended to allow us to create product that better meets individual consumer needs, including more specialization ofour category approach, while re-aligning and simplifying our offense to accelerate our largest growth opportunities.
# Manual label: Non-ESG
# FinBERT label: Product Liability
# FinBERT score:  0.6435078978538513
# --------------------------------------------------
#
# Sentence number: 115
# Sentence: NIKE is uniquely positioned to focus our community investments to address the global crisis of physical inactivity in kids and make in
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9862226843833923
# --------------------------------------------------
#
# Sentence number: 116
# Sentence: With a strategy based on creating awareness, driving commitment, and building capabilities within our supply chain, we hit our FY20 water reduction target 18 months early
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9815521836280823
# --------------------------------------------------
#
# Sentence number: 117
# Sentence: In FY21, the NIKE water program was recognized by the Brave Blue World Foundation as a global leader and industry role model for driving water sustainability in the footwear/apparel supply chain.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.982284665107727
# --------------------------------------------------
#
# Sentence number: 118
# Sentence: These investments have helped to drive significant, positive change for kids and communities around the world.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9891581535339355
# --------------------------------------------------
#
# Sentence number: 119
# Sentence: In partnership with NIKE’s Responsible Sourcing and Manufacturing teams, we also piloted the industry-leading Social Labor Convergence Program’s (SLCP) EHS self-assessment module and verification at select global logistics operations.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9865812063217163
# --------------------------------------------------
#
# Sentence number: 120
# Sentence: By the end of FY20, freshwater use was 119 liters per kilogram, a 42% reduction from the baseline.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9802394509315491
# --------------------------------------------------
#
# Sentence number: 121
# Sentence: The SSC is a group of 11 strategic suppliers committed to innovating and scaling sustainability programs to enhance their operational performance and mitigate risk while sharing out best practices in the hopes of elevating worker safety across the sector.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9947972893714905
# --------------------------------------------------
#
# Sentence number: 122
# Sentence: Avoid any actions that are at odds, or could appear to be at odds, with the interests of Nike
# Manual label: Business Ethics & Values
# FinBERT label: Corporate Governance
# FinBERT score:  0.7833423614501953
# --------------------------------------------------
#
# Sentence number: 123
# Sentence: In 2016, we signed the White House Equal Pay Pledge and have developed an ongoing discipline of reviewing our pay practices annually to achieve and maintain pay equity for our approximately 75,000 teammates across all geographies, functions and business units.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.8964877724647522
# --------------------------------------------------
#
# Sentence number: 124
# Sentence: In fiscal 2021, NIKE, Inc. achieved record Revenues which increased 19% to $44.5 billion.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9920021295547485
# --------------------------------------------------
#
# Sentence number: 125
# Sentence: As a result, all 13 at-risk facilities that were determined to be high risk have now implemented water-risk mitigation plans.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9850769639015198
# --------------------------------------------------
#
# Sentence number: 126
# Sentence: We bring it to life through our Code of Conduct — our roadmap that we expect NIKE, Inc. employees to follow to comply with laws and ethical practices.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9831904172897339
# --------------------------------------------------
#
# Sentence number: 127
# Sentence: Since fiscal 2018, through the Consumer Direct Offense and our Triple Double strategy, we have focused on doubling the impact of innovation, increasing our speed and agilityto market and growing our direct connections with consumers.
# Manual label: Non-ESG
# FinBERT label: Product Liability
# FinBERT score:  0.8998915553092957
# --------------------------------------------------
#
# Sentence number: 128
# Sentence: Our cleaner chemistry work begins with our foundational requirements set forth in the Code, requiring all suppliers to properly manage chemistry and create approaches to meet our Restricted Substances List (RSL) and MRSL requirements.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.8903815746307373
# --------------------------------------------------
#
# Sentence number: 129
# Sentence: The majority of NIKE’s packaging in footwear is produced with over 90% recycled content.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9881870150566101
# --------------------------------------------------
#
# Sentence number: 130
# Sentence: Multiple projects have been initiated to achieve our goal of reduced packaging.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9807008504867554
# --------------------------------------------------
#
# Sentence number: 131
# Sentence: From this relationship, NIKE developed a workplace safety facilitator program to develop soft skills so workers, managers and leaders can deliver peer-to-peer safety conversations on fire safety as well as other safety topics.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9955767393112183
# --------------------------------------------------
#
# Sentence number: 132
# Sentence: Our strategy goes beyond phase-out of PFCs but includes ensuring that we replace them with clean-chemistry alternatives, which demonstrates our ability to drive the adoption of better chemistry and maintain outstanding performance
# Manual label: Product Liability
# FinBERT label: Pollution & Waste
# FinBERT score:  0.7253244519233704
# --------------------------------------------------
#
# Sentence number: 133
# Sentence: In FY21, NIKE launched onsite solar programs in Vietnam and Indonesia, and suppliers added significant onsite solar PV capacity, with 25 facilities signing contracts for 32 MW of solar energy.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.995507001876831
# --------------------------------------------------
#
# Sentence number: 134
# ...
# FinBERT label: Human Capital
# FinBERT score:  0.9896780252456665
# --------------------------------------------------
#
# Sentence number: 185
# Sentence: The NIKE Political Action Committee is a voluntary organization where Company employees may participate.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9515719413757324
# --------------------------------------------------
#
# Sentence number: 186
# Sentence: In addition, the Far Eastern Group’s Vietnam facility delivered a 9.79% reduction by focusing on wastewater recycling using one of the largest textile wastewater recycling systems in all of Vietnam.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9874908328056335
# --------------------------------------------------
#
# Sentence number: 187
# Sentence: ROIC as of May 31, 2021, was 48.8% compared to 21.5% as of May31, 2020.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.982743501663208
# --------------------------------------------------
#
# Sentence number: 188
# Sentence: This resulted in a 30% reduction in phylon midsole defect waste, prevented more than 2.4 million kg of waste and prevented 9.4 million kg of associated carbon emissions.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.834245502948761
# --------------------------------------------------
#
# Sentence number: 189
# Sentence: Anti-bribery laws apply in every country where Nike does business.
# Manual label: Business Ethics & Values
# FinBERT label: Business Ethics & Values
# FinBERT score:  0.9790886044502258
# --------------------------------------------------
#
# Sentence number: 190
# Sentence: We expanded our COVID-19 Sick Leave Policy, which, in addition to existing paid time off benefits and legally mandated sick leave programs, provides up to two regularly scheduled work weeks of paid sick leave for those experiencing symptoms associated with COVID-19, or needing to take time off to care for their children due to school or childcare closure, and now includes mental and emotional well-being.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9505307674407959
# --------------------------------------------------
#
# Sentence number: 191
# Sentence: We are leveraging the momentum created in our supply chain during the FY20 target period that enabled us to achieve a 30% freshwater reduction to now commit to a FY25 water reduction target (on a liters per kilogram basis) of 25% from our FY20 baseline across our strategic materials vendors.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9852991104125977
# --------------------------------------------------
#
# Sentence number: 192
# Sentence: Throughout our phaseout, we have made a point of completing a toxicology assessment on all PFC alternatives to help enable better chemistry to be substituted into the supply chain.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.6353555917739868
# --------------------------------------------------
#
# Sentence number: 193
# Sentence: Finally, our EMEA distribution center closed the loop on being 100% plastic free for all digital and B2B packaging deliveries.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9783520698547363
# --------------------------------------------------
#
# Sentence number: 194
# Sentence: We are concentrating conversions to recycled polyester, organic cotton and recycled cotton content on key highvolume fabrics and products.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9309424757957458
# --------------------------------------------------
#
# Sentence number: 195
# Sentence: When we detect a chemical that exceeds our RSL standard, we work directly with our suppliers to increase chemical management capabilities and remediate the issue, ultimately creating a more capable supply chain.
# Manual label: Product Liability
# FinBERT label: Pollution & Waste
# FinBERT score:  0.7207940220832825
# --------------------------------------------------
#
# Sentence number: 196
# Sentence: The project will significantly reduce NIKE’s overall water footprint, as well as the ease the impact on supplies at a local level.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9889946579933167
# --------------------------------------------------
#
# Sentence number: 197
# Sentence: This puts NIKE among the top users of this key sustainable fiber globally
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.41324225068092346
# --------------------------------------------------
#
# Sentence number: 198
# Sentence: We have seen great progress with Scope 2 emissions, driven by renewable electricity through PPAs, vPPAs and onsite renewable energy
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9959191679954529
# --------------------------------------------------
#
# Sentence number: 199
# Sentence: Income (loss) before income taxes increased 131% for fiscal 2021, primarily due to higher revenues, gross margin expansion and selling and administrative expense leverage.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9934373497962952
# --------------------------------------------------
#
# Sentence number: 200
# Sentence: As the needs of our communities became clear last year, NIKE responded by investing more than ever before.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9884098768234253
# --------------------------------------------------
#
# Sentence number: 201
# Sentence: NIKE requires Tier 1 and strategic Tier 2 suppliers to adopt fire prevention and emergency action plans for the protection of workers during normal working operations and emergency situations.
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9946346282958984
# --------------------------------------------------
#
# Sentence number: 202
# Sentence: In recent years, the Board has had 10 – 14 directors, and it is the belief of the Board that this size permits diversity of experience without hindering effective discussion or diminishing individual accountability.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9937887787818909
# --------------------------------------------------
#
# Sentence number: 203
# Sentence: Over the past five years, we’ve consistently outperformed our goal of investing a minimum of 1.5% of prioryear pre-tax income to impact communities around the world.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9880937933921814
# --------------------------------------------------
#
# Sentence number: 204
# Sentence: These investments will aim to create impact at the intersection of race, gender, and orientation, and in turn, create opportunities and spaces for people to unite through the power of sport.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9354227185249329
# --------------------------------------------------
#
# Sentence number: 205
# Sentence: Historically, carbon emissions from outbound transportation (from a NIKE distribution center to final destination, including to the consumer) have been challenging with the growth of e-commerce sales, as we try to balance speed and carbon emissions.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9942392110824585
# --------------------------------------------------
#
# Sentence number: 206
# Sentence: During FY21, we raised our minimum hourly rate to $15 for retail store teammates in North America and increased our hourly rates for store employees across EMEA.2
# Manual label: Human Capital
# FinBERT label: Human Capital
# FinBERT score:  0.9855578541755676
# --------------------------------------------------
#
# Sentence number: 207
# Sentence: Whether it’s manufacturing protective equipment for healthcare workers or providing financial relief after devastating wildfires, we’re there to support our employees and the communities they call home.
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.6805389523506165
# --------------------------------------------------
#
# Sentence number: 208
# Sentence: Each year, we will provide grants to nonprofits working to level the playing field for the communities represented by our eight NIKE Employee Networks (NikeUNITED).
# Manual label: Community Relations
# FinBERT label: Community Relations
# FinBERT score:  0.9906512498855591
# --------------------------------------------------
#
# Sentence number: 209
# Sentence: During fiscal 2020, we entered into definitive agreements to sell our NIKE Brand businesses in Brazil, Argentina, Chile and Uruguay and to shift to a distributor operatingmodel.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9929744005203247
# --------------------------------------------------
#
# Sentence number: 210
# Sentence: We remain committed to effectively managing our business and mitigating financial market risks to achieve our financial goals over the long-term byexecuting against the operational strategies outlined above.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9025135636329651
# --------------------------------------------------
#
# Sentence number: 211
# Sentence: This strategy will lead with NIKE Digital and our owned stores, as well asthrough select strategic partners who share our marketplace vision.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.7223809361457825
# --------------------------------------------------
#
# Sentence number: 212
# Sentence: Under a business-as-usual scenario, NIKE expects emissions from manufacturing to increase by more than 30% over the next five years – which means that, to reduce absolute emissions during this time, we need to push beyond incremental reductions and unlock transformative solutions.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9913710355758667
# --------------------------------------------------
#
# Sentence number: 213
# Sentence: We achieved our water risk targets and significantly exceeded our water reduction target by engaging with our suppliers to create awareness, drive commitment, and build capability.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9883993864059448
# --------------------------------------------------
#
# Sentence number: 214
# Sentence: In this context, NIKE approaches governance with a view to enhancing long-term shareholder value.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9808761477470398
# --------------------------------------------------
#
# Sentence number: 215
# Sentence: Each year, we elevate the expectations of our supply chain to meet more stringent RSL standards, including expanded substances, lowering specific limits or new chemical bans.
# Manual label: Product Liability
# FinBERT label: Product Liability
# FinBERT score:  0.9429299831390381
# --------------------------------------------------
#
# Sentence number: 216
# Sentence: Innovation will be increasingly important, focusing on new recycling methods and material types that meet our product and consumer requirements.
# Manual label: Pollution & Waste
# FinBERT label: Pollution & Waste
# FinBERT score:  0.9783647656440735
# --------------------------------------------------
#
# Sentence number: 217
# Sentence: Our programs help to drive operational efficiencies and energy savings among our supply chain while also building operational resilience for a future where climate impacts are the norm.
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9958628416061401
# --------------------------------------------------
#
# Sentence number: 218
# Sentence: We know that materials account for approximately 70% of NIKE’s product carbon footprint
# Manual label: Climate Change
# FinBERT label: Climate Change
# FinBERT score:  0.9941015839576721
# --------------------------------------------------
#
# Sentence number: 219
# Sentence: Demand creation expense decreased primarily due to lower marketing and advertising expenses for our brand events and retailoperations, as well as lower sports marketing expenses as sporting events were postponed due to COVID-19.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9929355978965759
# --------------------------------------------------
#
# Sentence number: 220
# Sentence: Since FY16, our vendors have avoided using a cumulative 40 billion liters of freshwater – 12 billion from NIKE’s freshwater footprint, the rest from other brands, including our competitors, who source from the same suppliers.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9676832556724548
# --------------------------------------------------
#
# Sentence number: 221
# Sentence: However, we expect the future operating model to have a favorable impact on our overallprofitability as we reduce selling and administrative expenses, as well as lessen exposure to foreign exchange rate volatility.
# Manual label: Non-ESG
# FinBERT label: Non-ESG
# FinBERT score:  0.9906326532363892
# --------------------------------------------------
#
# Sentence number: 222
# Sentence: NIKE required suppliers to assess water-related risks, such as flooding and drought, and develop mitigation plans.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.987168550491333
# --------------------------------------------------
#
# Sentence number: 223
# Sentence: Specifically, through collaboration and engagement, sportswear multinational NIKE has encouraged its suppliers to explore ways of reducing water used in their manufacturing processes.
# Manual label: Natural Capital
# FinBERT label: Natural Capital
# FinBERT score:  0.9705307483673096
# --------------------------------------------------
#
# Sentence number: 224
# Sentence: In June 2020, we announced a new digitally empowered phase of the Consumer Direct Offense strategy:Consumer Direct Acceleration.
# Manual label: Non-ESG
# FinBERT label: Product Liability
# FinBERT score:  0.8538722395896912
# --------------------------------------------------
#
# Sentence number: 225
# Sentence: And the Board of Directors continues to actively oversee the company’s purpose, because we know that strong governance supports and enhances NIKE’s capacity to make progress.
# Manual label: Corporate Governance
# FinBERT label: Corporate Governance
# FinBERT score:  0.9944789409637451
# --------------------------------------------------
#      No.                                           Sentence Label  \
# 0      1  Importantly, our measure of MRSL compliance is...    PL
# 1      2  It assists NIKE, Inc. in accomplishing its obj...    CG
# 2      3  Internally, our Women of Nike & Friends Networ...    HC
# 3      4  In Belgium, at our Converse European Logistics...    CC
# 4      5  The Company will not make political contributi...    BE
# ..   ...                                                ...   ...
# 220  221  However, we expect the future operating model ...     N
# 221  222  NIKE required suppliers to assess water-relate...    NC
# 222  223  Specifically, through collaboration and engage...    NC
# 223  224  In June 2020, we announced a new digitally emp...     N
# 224  225  And the Board of Directors continues to active...    CG
#
#     FinBERT label  FinBERT score  Correct label
# 0              PL       0.781741              1
# 1              CG       0.976031              1
# 2              HC       0.811219              1
# 3              CC       0.995495              1
# 4              BE       0.968667              1
# ..            ...            ...            ...
# 220             N       0.990633              1
# 221            NC       0.987169              1
# 222            NC       0.970531              1
# 223            PL       0.853872              0
# 224            CG       0.994479              1
#
# [225 rows x 6 columns]

# %% [markdown]
# ## 3. Evaluate FinBERT performance (only if you already have label)

# %%
# evaluate the FinBERT performance
from sklearn.metrics import accuracy_score, precision_score, recall_score

# select which output to evaluate: result_df_full or result_df_label
# eval = result_df_full
eval = result_df_label

print('Accuracy score: ', accuracy_score(eval['Label'], eval['FinBERT label']))
print('Precision score: ', precision_score(eval['Label'], eval['FinBERT label'], average = 'macro'))
print('Recall score: ', recall_score(eval['Label'], eval['FinBERT label'], average = 'macro'))
# Out:
# Accuracy score:  0.9333333333333333
# Precision score:  0.9334194814316596
# Recall score:  0.9333333333333333

# %% [markdown]
# ## 4. Try a single sentence

# %%
# paste any sentence here within the quotation marks
sentence = 'For 2002, our total net emissions were approximately 60 million metric tons of CO2 equivalents for all businesses and operations we have ﬁnancial interests in, based on its equity share in those businesses and operations.'
results = nlp(sentence)

# get FinBERT labels and scores
finbert_output = nlp(sentence)[0]
finbert_label = finbert_output['label']
finbert_score = finbert_output['score']

print('Sentence: ' + sentence)
print('FinBERT label: ' + finbert_label)
print('FinBERT score: ', finbert_score)
# Out:
# Sentence: For 2002, our total net emissions were approximately 60 million metric tons of CO2 equivalents for all businesses and operations we have ﬁnancial interests in, based on its equity share in those businesses and operations.
# FinBERT label: Climate Change
# FinBERT score:  0.9955655932426453

# %% [markdown]
# ## 5. Try an unlabeled dataset

# %%
# !pip install transformers
from transformers import BertTokenizer, BertForSequenceClassification, pipeline

# load the FinBERT fine-tuned ESG 9-category model and the corresponding tokernizer
finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-esg-9-categories', num_labels = 9)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-esg-9-categories')

# load model on GPU/CPU
import torch
# load model on GPU if available
if torch.cuda.is_available():
    device = torch.device("cuda")
    # put the model on GPU
    finbert.to(device)
    print(f'There are {torch.cuda.device_count()} GPU(s) available.')
    print('Model loaded on:', torch.cuda.get_device_name(0))

# load model on CPU if GPU is not available
else:
    device = torch.device("cpu")
    # put the model on CPU
    finbert.to(device)
    print('No GPU available, model loaded on CPU.')

import pandas as pd

# import sample data
data = pd.read_csv('https://github.com/allenhhuang/FinBERT/raw/main/FinBERT%20test%20sample.csv').dropna(subset = ['Sentence']).reset_index(drop = True)

# 9 categories and labels
label_map = {'Climate Change': 'CC',
             'Natural Capital': 'NC',
             'Pollution & Waste': 'PW',
             'Human Capital': 'HC',
             'Product Liability': 'PL',
             'Community Relations': 'CR',
             'Corporate Governance': 'CG',
             'Business Ethics & Values': 'BE',
             'Non-ESG': 'N'}

# use pipeline in transformers to assemble the steps of finbert prediction
if torch.cuda.is_available(): # has GPU
  nlp = pipeline("text-classification", model = finbert, tokenizer = tokenizer, device = 0)
else: # CPU only
  nlp = pipeline("text-classification", model = finbert, tokenizer = tokenizer)

# define the output structure
header = ['No.', 'Sentence', 'FinBERT label', 'FinBERT score']
result = []

# loop through the sentences
for i, row in data.iterrows():

  # sentence number
  id = str(i+1)
  # sentence
  sentence = row['Sentence']

  # use the nlp function to process the sentence, get finbert label and score
  finbert_output = nlp(sentence)[0]

  # label and score
  finbert_label = label_map[finbert_output['label']]
  finbert_score = finbert_output['score']

  # combine all the output above into one row of observation
  row = [id, sentence, finbert_label, finbert_score]
  result.append(row)

# consolidate the output into a dataframe
result_df_label = pd.DataFrame(result, columns = header)

# save the output in the csv format
result_df_label.to_csv('FinBERT ESG9Class prediction.csv', index = False)
# download the output to the local computer
from google.colab import files
files.download('FinBERT ESG9Class prediction.csv')
# display the output
result_df_label
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# There are 1 GPU(s) available.
# Model loaded on: Tesla T4
#      No.                                           Sentence FinBERT label  \
# 0      1  Importantly, our measure of MRSL compliance is...            PL
# 1      2  It assists NIKE, Inc. in accomplishing its obj...            CG
# 2      3  Internally, our Women of Nike & Friends Networ...            HC
# 3      4  In Belgium, at our Converse European Logistics...            CC
# 4      5  The Company will not make political contributi...            BE
# ..   ...                                                ...           ...
# 220  221  However, we expect the future operating model ...             N
# 221  222  NIKE required suppliers to assess water-relate...            NC
# 222  223  Specifically, through collaboration and engage...            NC
# 223  224  In June 2020, we announced a new digitally emp...            PL
# 224  225  And the Board of Directors continues to active...            CG
#
#      FinBERT score
# 0         0.781741
# 1         0.976031
# 2         0.811219
# 3         0.995495
# 4         0.968667
# ..             ...
# 220       0.990633
# 221       0.987169
# 222       0.970531
# 223       0.853872
# 224       0.994479
#
# [225 rows x 4 columns]
